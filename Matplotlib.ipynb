# %% [markdown]
# ### Loading the libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Basic Graph

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize the graph
plt.figure(figsize=(4.5,3), dpi=150)

#plt.plot(x,y, label = '2x', color = 'red', linewidth = 3, linestyle = '--', marker = '.', markersize = 10, markeredgecolor = 'blue')

# Use shorthand notation
#fmt = '[color][marker][line]'
plt.plot(x, y, 'r.--', label = '2x', linewidth = 3, markersize = 10, markeredgecolor = 'blue')

## Line number two
x2 = np.arange(0, 4.5, 0.5)
plt.plot(x2, x2 ** 2, label = 'x^2')

plt.title("First Graph", fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X axis')
plt.ylabel('Y axis')

plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])

plt.legend()

plt.savefig('mygraph.png', dpi=300)

plt.show()

# %% [markdown]
# ### Bar Chart

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

bars = plt.bar(labels, values)

#bars[0].set_hatch('/')
#bars[1].set_hatch('O')
#bars[2].set_hatch('*')

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.figure(figsize = (6,4))

plt.show()
